# %% [markdown]
# # Install Dependencies

# %%
# !python -m pip install pymupdf langchain langchain-community langchain-text-splitters langchain-ollama sentence-transformers faiss-cpu rank-bm25 transformers ragas scikit-learn pandas numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !{sys.executable} -m pip install --force-reinstall langchain-text-splitters
# Out:
# zsh:1: parse error near `-m'

# %% [markdown]
# # Import Libraries

# %%
import fitz
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.retrievers import BM25Retriever
from langchain.retrievers import EnsembleRetriever, ContextualCompressionRetriever
from langchain_community.llms import Ollama
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from transformers import pipeline
import numpy as np
from sklearn.metrics import ndcg_score
import pandas as pd
from time import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import fitz
# ----> 3 from langchain_text_splitters import (
#       4     RecursiveCharacterTextSplitter,
#       5     CharacterTextSplitter
#       6 )
#       8 from langchain_community.embeddings import HuggingFaceEmbeddings
#       9 from langchain_community.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'langchain_text_splitters'
